# %% [markdown]
# # 📝 Ejercicios — Priority Queue ADT e Implementaciones con Listas
#
# ## Programación III - Lic. en Sistemas
#
# ---
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CristianPacifico/prog3-ls-fcad-uner/blob/main/cap09/Ejercicios_Clase1_PQ_Listas.ipynb)
#
#
# ### 📋 Ejercicios
#
# | # | Título | Dificultad | Tiempo |
# |---|--------|-----------|--------|
# | 1 | Traza manual de operaciones PQ | 🟢 Básico | 20 min |
# | 2 | Implementar UnsortedPriorityQueue from scratch | 🟡 Intermedio | 30 min |
# | 3 | Implementar SortedPriorityQueue from scratch | 🟡 Intermedio | 30 min |
# | 4 | Comparar implementaciones con benchmark | 🟡 Intermedio | 20 min |
# | 5 | PQ para simular sala de emergencias | 🔴 Avanzado | 30 min |
#
# ---
#
# > **Instrucciones:** Completar el código donde dice `# TU CÓDIGO AQUÍ` y ejecutar la celda para verificar.

# %% [markdown]
# ---
#
# ## 🟢 Ejercicio 1 — Traza Manual de Operaciones
#
# ### Contexto
#
# Dada la siguiente secuencia de operaciones sobre una **cola de prioridad vacía**,
# completar la tabla indicando qué retorna cada operación y el estado de la cola.
#
# ```
# P.add(4, 'D')
# P.add(2, 'B')
# P.add(7, 'G')
# P.add(1, 'A')
# P.min()
# P.remove_min()
# P.add(3, 'C')
# P.remove_min()
# P.remove_min()
# len(P)
# ```
#
# ### Completar la tabla:
#
# | Operación | Retorna | Estado de P (pares ordenados por clave) |
# |-----------|---------|----------------------------------------|
# | `P.add(4, 'D')` | — | `{(4,D)}` |
# | `P.add(2, 'B')` | — | ??? |
# | `P.add(7, 'G')` | — | ??? |
# | `P.add(1, 'A')` | — | ??? |
# | `P.min()` | ??? | ??? |
# | `P.remove_min()` | ??? | ??? |
# | `P.add(3, 'C')` | — | ??? |
# | `P.remove_min()` | ??? | ??? |
# | `P.remove_min()` | ??? | ??? |
# | `len(P)` | ??? | ??? |

# %%
# Ejercicio 1: Verificar tu traza ejecutando las operaciones
# Primero haz la traza manualmente en la tabla de arriba, ¡luego verifica aquí!

class Empty(Exception): pass
class PriorityQueueBase:
    class _Item:
        __slots__ = '_key', '_value'
        def __init__(self, k, v): self._key = k; self._value = v
        def __lt__(self, other): return self._key < other._key
        def __repr__(self): return f'({self._key},{self._value!r})'
    def is_empty(self): return len(self) == 0

class UnsortedPriorityQueue(PriorityQueueBase):
    def __init__(self): self._data = []
    def __len__(self): return len(self._data)
    def _find_min(self):
        if self.is_empty(): raise Empty()
        return min(range(len(self._data)), key=lambda i: self._data[i])
    def add(self, k, v): self._data.append(self._Item(k, v))
    def min(self):
        i = self._find_min(); item = self._data[i]; return (item._key, item._value)
    def remove_min(self):
        i = self._find_min(); item = self._data.pop(i); return (item._key, item._value)
    def __repr__(self):
        items = sorted(self._data, key=lambda x: x._key)
        return '{' + ', '.join(str(i) for i in items) + '}'

# Ejecutar y verificar
P = UnsortedPriorityQueue()
print('Traza de operaciones:')
print(f'add(4,D)       → {P.add(4,"D")} | estado: {P}')
print(f'add(2,B)       → {P.add(2,"B")} | estado: {P}')
print(f'add(7,G)       → {P.add(7,"G")} | estado: {P}')
print(f'add(1,A)       → {P.add(1,"A")} | estado: {P}')
print(f'min()          → {P.min()}')
print(f'remove_min()   → {P.remove_min()} | estado: {P}')
print(f'add(3,C)       → {P.add(3,"C")} | estado: {P}')
print(f'remove_min()   → {P.remove_min()} | estado: {P}')
print(f'remove_min()   → {P.remove_min()} | estado: {P}')
print(f'len(P)         → {len(P)}')

# %% [markdown]
# ---
#
# ## 🟡 Ejercicio 2 — Implementar `UnsortedPriorityQueue` desde Cero
#
# ### Enunciado
#
# Implementar la clase `MyUnsortedPQ` que:
#
# 1. Hereda de `PriorityQueueBase`
# 2. Usa una lista Python como estructura interna
# 3. Implementa `__len__`, `add`, `min`, `remove_min`
# 4. **`add`** en O(1) — insertar al final
# 5. **`min` y `remove_min`** en O(n) — buscar el mínimo recorriendo
#
# > 💡 **Pista:** La clave de la eficiencia está en el método `_find_min()`.
# > Usa `_Item.__lt__` para comparar elementos.

# %%
class MyUnsortedPQ(PriorityQueueBase):
    """EJERCICIO: Tu implementación de UnsortedPriorityQueue."""

    def __init__(self):
        # TU CÓDIGO AQUÍ: inicializar la lista interna
        pass

    def __len__(self):
        # TU CÓDIGO AQUÍ: retornar número de elementos
        pass

    def _find_min(self):
        # TU CÓDIGO AQUÍ: retornar índice del elemento con clave mínima
        # Lanzar Empty si está vacía
        pass

    def add(self, key, value):
        # TU CÓDIGO AQUÍ: insertar en O(1)
        pass

    def min(self):
        # TU CÓDIGO AQUÍ: retornar (k,v) del mínimo sin eliminar
        pass

    def remove_min(self):
        # TU CÓDIGO AQUÍ: eliminar y retornar (k,v) del mínimo
        pass


# ── Tests automáticos ──
def test_pq(cls, name):
    print(f'Testeando {name}...')
    P = cls()
    assert P.is_empty(), 'Debe estar vacía al inicio'
    P.add(5, 'E'); P.add(2, 'B'); P.add(8, 'H'); P.add(1, 'A'); P.add(3, 'C')
    assert len(P) == 5, f'len debe ser 5, es {len(P)}'
    assert P.min() == (1, 'A'), f'min() debe ser (1,A), es {P.min()}'
    assert P.remove_min() == (1, 'A'), 'remove_min debe retornar (1,A)'
    assert P.remove_min() == (2, 'B'), 'remove_min debe retornar (2,B)'
    assert len(P) == 3
    P.add(0, 'Z')
    assert P.min() == (0, 'Z'), 'Nuevo mínimo debe ser (0,Z)'
    assert P.remove_min() == (0, 'Z')
    # Extraer todo en orden
    result = []
    while not P.is_empty():
        result.append(P.remove_min())
    assert result == [(3,'C'), (5,'E'), (8,'H')], f'Orden incorrecto: {result}'
    print(f'  ✅ {name}: todos los tests pasaron!')

try:
    test_pq(MyUnsortedPQ, 'MyUnsortedPQ')
except Exception as e:
    print(f'  ❌ Error: {e}')

# %% [markdown]
# ---
#
# ## 🟡 Ejercicio 3 — Implementar `SortedPriorityQueue` desde Cero
#
# ### Enunciado
#
# Implementar `MySortedPQ` que mantiene los elementos **siempre ordenados**:
#
# 1. **`add(k, v)`** en O(n) — buscar la posición correcta e insertar
# 2. **`min()` y `remove_min()`** en O(1) — el mínimo está siempre en el índice 0
#
# > 💡 **Pista para `add`:** Recorrer de derecha a izquierda mientras `new_item < self._data[idx-1]`, luego usar `list.insert(idx, item)`.

# %%
class MySortedPQ(PriorityQueueBase):
    """EJERCICIO: Tu implementación de SortedPriorityQueue."""

    def __init__(self):
        # TU CÓDIGO AQUÍ
        pass

    def __len__(self):
        # TU CÓDIGO AQUÍ
        pass

    def add(self, key, value):
        # TU CÓDIGO AQUÍ: insertar en la posición correcta para mantener orden
        # El mínimo debe quedar en el índice 0
        pass

    def min(self):
        # TU CÓDIGO AQUÍ: retornar (k,v) del frente sin eliminar
        pass

    def remove_min(self):
        # TU CÓDIGO AQUÍ: eliminar y retornar (k,v) del frente
        pass


# ── Tests automáticos (mismos que antes) ──
try:
    test_pq(MySortedPQ, 'MySortedPQ')
    # Test adicional: verificar orden interno
    Q = MySortedPQ()
    for x in [9, 3, 7, 1, 5]:
        Q.add(x, str(x))
    keys = [Q._data[i]._key for i in range(len(Q))]
    assert keys == sorted(keys), f'La lista interna no está ordenada: {keys}'
    print('  ✅ Lista interna ordenada correctamente!')
except Exception as e:
    print(f'  ❌ Error: {e}')

# %% [markdown]
# ---
#
# ## 🟡 Ejercicio 4 — Benchmark y Análisis Experimental
#
# ### Enunciado
#
# Completar la función `benchmark_and_compare` que:
# 1. Crea instancias de ambas PQ
# 2. Mide el tiempo de inserción de N elementos aleatorios
# 3. Mide el tiempo de extracción de todos los elementos
# 4. Verifica que la salida esté ordenada
# 5. Imprime una tabla comparativa

# %%
import time, random

def benchmark_and_compare(N, seed=42):
    """EJERCICIO: Completar el benchmark comparativo."""
    random.seed(seed)
    keys = [random.randint(1, N*10) for _ in range(N)]
    
    results = {}
    
    for name, cls in [('UnsortedPQ', UnsortedPriorityQueue), ('SortedPQ', MySortedPQ)]:
        pq = cls()
        
        # TU CÓDIGO AQUÍ: medir tiempo de inserción
        t_add = 0  # reemplazar con medición real
        
        # TU CÓDIGO AQUÍ: medir tiempo de extracción y verificar orden
        t_remove = 0  # reemplazar con medición real
        is_sorted = True  # reemplazar con verificación real
        
        results[name] = (t_add * 1000, t_remove * 1000, is_sorted)
    
    # TU CÓDIGO AQUÍ: imprimir tabla de resultados
    print(f'N = {N}')
    print(f'{"Impl":12} | {"add (ms)":>10} | {"remove (ms)":>12} | {"Ordenado":>9}')
    print('-' * 55)
    for name, (ta, tr, ok) in results.items():
        print(f'{name:12} | {ta:>10.2f} | {tr:>12.2f} | {str(ok):>9}')

# Ejecutar para varios N
for N in [100, 500, 1000]:
    benchmark_and_compare(N)
    print()

# %% [markdown]
# ---
#
# ## 🔴 Ejercicio 5 — Simulación de Sala de Emergencias
#
# ### Enunciado
#
# Implementar una simulación de una sala de emergencias hospitalaria usando una Priority Queue.
#
# **Reglas:**
# - Cada paciente llega con un **nivel de urgencia** (1=crítico, 2=urgente, 3=moderado, 4=leve)
# - Los pacientes se atienden en orden de **mayor urgencia** (menor número primero)
# - Si dos pacientes tienen el **mismo nivel de urgencia**, se atiende al que llegó **primero** (FIFO)
# - Implementar: `llega_paciente(nombre, urgencia)`, `atender_siguiente()`, `mostrar_espera()`
#
# > 💡 **Pista para FIFO con misma urgencia:** Usa una clave compuesta `(urgencia, orden_llegada)` como la clave de la PQ.

# %%
class SalaEmergencias:
    """EJERCICIO: Simulación de sala de emergencias con Priority Queue."""
    
    # Niveles de urgencia
    URGENCIAS = {1: '🔴 CRÍTICO', 2: '🟠 URGENTE', 3: '🟡 MODERADO', 4: '🟢 LEVE'}
    
    def __init__(self):
        # TU CÓDIGO AQUÍ: inicializar la PQ y el contador de llegadas
        pass
    
    def llega_paciente(self, nombre, urgencia):
        """Registrar llegada de un paciente.
        urgencia: 1 (crítico) a 4 (leve)
        Implementar FIFO para igual urgencia.
        """
        # TU CÓDIGO AQUÍ
        pass
    
    def atender_siguiente(self):
        """Atender al paciente con mayor urgencia (menor clave).
        Retornar nombre del paciente o None si no hay pacientes.
        """
        # TU CÓDIGO AQUÍ
        pass
    
    def mostrar_espera(self):
        """Mostrar lista de pacientes en espera ordenados por prioridad."""
        # TU CÓDIGO AQUÍ: mostrar todos los pacientes de mayor a menor urgencia
        pass
    
    def hay_pacientes(self):
        # TU CÓDIGO AQUÍ
        pass


# ── Simulación ──
sala = SalaEmergencias()

# Llegadas de pacientes
sala.llega_paciente('Carlos',  urgencia=3)
sala.llega_paciente('Ana',     urgencia=1)
sala.llega_paciente('Beatriz', urgencia=2)
sala.llega_paciente('David',   urgencia=1)   # Mismo nivel que Ana → debe esperar
sala.llega_paciente('Elena',   urgencia=4)
sala.llega_paciente('Felipe',  urgencia=2)

print('=== Estado inicial de la sala ===')
sala.mostrar_espera()

print()
print('=== Atendiendo pacientes en orden de urgencia ===')
while sala.hay_pacientes():
    paciente = sala.atender_siguiente()
    print(f'  Atendido: {paciente}')

# %% [markdown]
# ---
#
# ## 📝 Resumen — Clase 1
#
# ### Lo que practicaste
#
# | Ejercicio | Concepto | Estado |
# |-----------|----------|--------|
# | 1 | Traza manual de operaciones | ✅ |
# | 2 | Implementación UnsortedPQ | ✅ |
# | 3 | Implementación SortedPQ | ✅ |
# | 4 | Benchmark comparativo | ✅ |
# | 5 | Aplicación práctica real | ✅ |
#
# ### Puntos clave recordar
#
# - **Clave = Prioridad**: menor clave → mayor prioridad
# - **Unsorted**: add O(1), min O(n) — lazy strategy
# - **Sorted**: add O(n), min O(1) — eager strategy
# - Para FIFO con iguales: usar clave compuesta `(prioridad, timestamp)`
#
# ---
#
# 🔗 **Siguiente clase:** Heaps y Heap-Sort — eficiencia O(log n) garantizada.
#
# ---
#
# ![Creative Commons](https://mirrors.creativecommons.org/presskit/buttons/80x15/png/by-sa.png)
#
# © 2026 Cátedra Programación III – Lic. Sistemas – FCAD/UNER
#
# This notebook is licensed under a Creative Commons Attribution-ShareAlike 4.0 International License (CC BY-SA 4.0)
#
# <https://creativecommons.org/licenses/by-sa/4.0/>
